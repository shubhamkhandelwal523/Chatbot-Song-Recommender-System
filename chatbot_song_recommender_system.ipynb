# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install anvil-uplink
# Out:
# Requirement already satisfied: anvil-uplink in /usr/local/lib/python3.7/dist-packages (0.3.42)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (0.16.0)
# Requirement already satisfied: ws4py in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (0.5.1)
# Collecting argparse
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %%
import anvil.server

anvil.server.connect("TYIRZOOL7NRIXVOS4F4S4COP-SLOBDN67A3SHKBDS")
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default environment" as SERVER

# %%
# pip install tensorflow keras pickle nltk
from google.colab import drive
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
intents_file = open('/content/drive/MyDrive/Colab Notebooks/intents.json').read()
intents = json.loads(intents_file)

# %%
import nltk
nltk.download('punkt')
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [(['hi'], 'greeting'), (['hello'], 'greeting'), (['whats', 'up'], 'greeting'), (['sup'], 'greeting'), (['is', 'anyone', 'there'], 'greeting'), (['whats', 'good'], 'greeting'), (['hey'], 'greeting'), (['bye'], 'goodbye'), (['cya'], 'goodbye'), (['see', 'you', 'later'], 'goodbye'), (['goodbye'], 'goodbye'), (['im', 'leaving'], 'goodbye'), (['have', 'a', 'good', 'day'], 'goodbye'), (['how', 'old', 'are', 'you'], 'age'), (['what', 'is', 'your', 'age'], 'age'), (['thanks'], 'thanks'), (['thank', 'you'], 'thanks'), (['thankyou'], 'thanks'), (['ty'], 'thanks'), (['I', 'owe', 'you', 'one'], 'thanks'), (['whats', 'is', 'your', 'name'], 'name'), (['whats', 'your', 'name'], 'name'), (['whats', 'should', 'I', 'call', 'you'], 'name'), (['how', 'should', 'I', 'address', 'you'], 'name'), (['Yes', 'it', 'does'], 'sky_net_yes'), (['Yeah'], 'sky_net_yes'), (['Haha', 'yep'], 'sky_net_yes'), (['yes'], 'sky_net_yes'), (['Indeed'], 'sky_net_yes'), (['Yup'], 'sky_net_yes'), (['Just', 'like', 'the', 'terminator'], 'sky_net_yes'), (['no'], 'sky_net_no'), (['nah'], 'sky_net_no'), (['not', 'really'], 'sky_net_no'), (['thats', 'scary'], 'sky_net_no'), (['singularity'], 'sky_net_no'), (['how', 'are', 'you'], 'how_are_you'), (['how', 'are', 'you', 'doing'], 'how_are_you'), (['what', 'is', 'going', 'on'], 'how_are_you'), (['I', 'am', 'doing', 'great'], 'doing_great'), (['I', 'am', 'well'], 'doing_great'), (['Im', 'great'], 'doing_great'), (['awesome'], 'doing_great'), (['happy'], 'doing_great'), (['better'], 'doing_great'), (['not', 'great'], 'doing_badly'), (['not', 'well'], 'doing_badly'), (['not', 'good'], 'doing_badly'), (['bad'], 'doing_badly'), (['badly'], 'doing_badly'), (['terrible'], 'doing_badly'), (['horrible'], 'doing_badly'), (['awful'], 'doing_badly'), (['sad'], 'doing_badly'), (['wait', 'you', 'watch', 'Netflix'], 'netflix'), (['how', 'do', 'you', 'watch', 'Netflix'], 'netflix'), (['Netflix'], 'netflix'), (['how', 'can', 'you', 'run'], 'quick_run'), (['how', 'do', 'you', 'run'], 'quick_run'), (['how', 'run'], 'quick_run'), (['why', 'run'], 'quick_run'), (['run'], 'quick_run'), (['you', 'real'], 'real_bot'), (['you', 'human'], 'real_bot'), (['you', 'robot'], 'real_bot'), (['you', 'alive'], 'real_bot'), (['you', 'sentient'], 'real_bot'), (['you', 'conscious'], 'real_bot'), (['tell', 'me', 'joke'], 'joke'), (['got', 'any', 'good', 'jokes'], 'joke'), (['got', 'jokes'], 'joke'), (['can', 'you', 'tell', 'joke'], 'joke'), (['tell', 'joke'], 'joke'), (['haha'], 'good_joke'), (['that', 'was', 'funny'], 'good_joke'), (['very', 'funny'], 'good_joke'), (['good', 'one'], 'good_joke'), (['bad', 'joke'], 'bad_joke'), (['trash', 'joke'], 'bad_joke'), (['terrible'], 'bad_joke'), (['not', 'funny'], 'bad_joke'), (['I', 'hate', 'you'], 'hate'), (['you', 'stupid'], 'hate'), (['you', 'dumb'], 'hate'), (['you', 'mean'], 'hate'), (['you', 'my', 'friend'], 'like'), (['I', 'like', 'you'], 'like'), (['I', 'love', 'you'], 'like'), (['you', 'cool'], 'like'), (['you', 'are', 'chill'], 'like'), (['whats', 'favorite', 'show'], 'favorite_show'), (['favorite', 'tv', 'show'], 'favorite_show'), (['Whats', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'film'], 'favorite_movie'), (['best', 'movie'], 'favorite_movie'), (['your', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'movie'], 'favorite_movie'), (['What', 'think', 'about'], 'your_thoughts'), (['What', 'your', 'thoughts'], 'your_thoughts')]

# %%
import nltk
nltk.download('wordnet')
# create the training data
training = []
# create empty array for the output
output_empty = [0] * len(classes)
# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words

    bag = []
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)
# create training and testing lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data is created")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Training data is created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# deep neural networds model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# Epoch 1/200
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 20/20 [==============================] - 1s 2ms/step - loss: 3.1260 - accuracy: 0.0606
# Epoch 2/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.9716 - accuracy: 0.1313
# Epoch 3/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.8403 - accuracy: 0.2222
# Epoch 4/200
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6831 - accuracy: 0.2626
# Epoch 5/200
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6173 - accuracy: 0.2626
# Epoch 6/200
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5737 - accuracy: 0.2222
# Epoch 7/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.4085 - accuracy: 0.2929
# Epoch 8/200
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3158 - accuracy: 0.2727
# Epoch 9/200
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2094 - accuracy: 0.2828
# Epoch 10/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.0888 - accuracy: 0.3737
# Epoch 11/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.9572 - accuracy: 0.4040
# Epoch 12/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.0877 - accuracy: 0.3333
# Epoch 13/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.9813 - accuracy: 0.3535
# Epoch 14/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7544 - accuracy: 0.4848
# Epoch 15/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8494 - accuracy: 0.4040
# Epoch 16/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7973 - accuracy: 0.4444
# Epoch 17/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7135 - accuracy: 0.4343
# Epoch 18/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5682 - accuracy: 0.5051
# Epoch 19/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4980 - accuracy: 0.5455
# Epoch 20/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5944 - accuracy: 0.4848
# Epoch 21/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4871 - accuracy: 0.5556
# Epoch 22/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.6013 - accuracy: 0.4949
# Epoch 23/200
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4760 - accuracy: 0.5253
# Epoch 24/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5437 - accuracy: 0.5051
# Epoch 25/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5627 - accuracy: 0.5556
# Epoch 26/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3649 - accuracy: 0.6263
# Epoch 27/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4283 - accuracy: 0.5152
# Epoch 28/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3540 - accuracy: 0.5657
# Epoch 29/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1570 - accuracy: 0.6364
# Epoch 30/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0717 - accuracy: 0.6263
# Epoch 31/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1838 - accuracy: 0.6263
# Epoch 32/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1173 - accuracy: 0.6465
# Epoch 33/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9838 - accuracy: 0.6465
# Epoch 34/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9927 - accuracy: 0.6869
# Epoch 35/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0149 - accuracy: 0.6768
# Epoch 36/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0362 - accuracy: 0.7172
# Epoch 37/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9495 - accuracy: 0.6768
# Epoch 38/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.9994 - accuracy: 0.6465
# Epoch 39/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8344 - accuracy: 0.6970
# Epoch 40/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7920 - accuracy: 0.7374
# Epoch 41/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.9607 - accuracy: 0.6869
# Epoch 42/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8682 - accuracy: 0.6970
# Epoch 43/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8470 - accuracy: 0.6667
# Epoch 44/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0524 - accuracy: 0.5859
# Epoch 45/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9097 - accuracy: 0.7071
# Epoch 46/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8441 - accuracy: 0.7172
# Epoch 47/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8802 - accuracy: 0.7071
# Epoch 48/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7634 - accuracy: 0.7677
# Epoch 49/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7531 - accuracy: 0.7475
# Epoch 50/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7519 - accuracy: 0.7576
# Epoch 51/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7845 - accuracy: 0.7172
# Epoch 52/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6464 - accuracy: 0.7879
# Epoch 53/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6893 - accuracy: 0.7374
# Epoch 54/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7802 - accuracy: 0.7475
# Epoch 55/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7406 - accuracy: 0.7071
# Epoch 56/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.9010 - accuracy: 0.6566
# Epoch 57/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.8640 - accuracy: 0.6970
# Epoch 58/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.8242 - accuracy: 0.7273
# Epoch 59/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7958 - accuracy: 0.7475
# Epoch 60/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6892 - accuracy: 0.7879
# Epoch 61/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8185 - accuracy: 0.7677
# Epoch 62/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7232 - accuracy: 0.7677
# Epoch 63/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6663 - accuracy: 0.7778
# Epoch 64/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6595 - accuracy: 0.7778
# Epoch 65/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5682 - accuracy: 0.7879
# Epoch 66/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6382 - accuracy: 0.8081
# Epoch 67/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8251 - accuracy: 0.7273
# Epoch 68/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5301 - accuracy: 0.7879
# Epoch 69/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7319 - accuracy: 0.7576
# Epoch 70/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7673 - accuracy: 0.7273
# Epoch 71/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7235 - accuracy: 0.7778
# Epoch 72/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5361 - accuracy: 0.8283
# Epoch 73/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6837 - accuracy: 0.6970
# Epoch 74/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6337 - accuracy: 0.7677
# Epoch 75/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6359 - accuracy: 0.7677
# Epoch 76/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6060 - accuracy: 0.8182
# Epoch 77/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7217 - accuracy: 0.7980
# Epoch 78/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5492 - accuracy: 0.7980
# Epoch 79/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6809 - accuracy: 0.7172
# Epoch 80/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5473 - accuracy: 0.7778
# Epoch 81/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5197 - accuracy: 0.8081
# Epoch 82/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7166 - accuracy: 0.7172
# Epoch 83/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5648 - accuracy: 0.8283
# Epoch 84/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6247 - accuracy: 0.7778
# Epoch 85/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5633 - accuracy: 0.7879
# Epoch 86/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6998 - accuracy: 0.7576
# Epoch 87/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6938 - accuracy: 0.7576
# Epoch 88/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6025 - accuracy: 0.7879
# Epoch 89/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6004 - accuracy: 0.7980
# Epoch 90/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6011 - accuracy: 0.7677
# Epoch 91/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7153 - accuracy: 0.7576
# Epoch 92/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6411 - accuracy: 0.7576
# Epoch 93/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6718 - accuracy: 0.7677
# Epoch 94/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4960 - accuracy: 0.7980
# Epoch 95/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6117 - accuracy: 0.7980
# Epoch 96/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5842 - accuracy: 0.7778
# Epoch 97/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6074 - accuracy: 0.7879
# Epoch 98/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5687 - accuracy: 0.8182
# Epoch 99/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6464 - accuracy: 0.7677
# Epoch 100/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4385 - accuracy: 0.8283
# Epoch 101/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5469 - accuracy: 0.7778
# Epoch 102/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5109 - accuracy: 0.8485
# Epoch 103/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6228 - accuracy: 0.8081
# Epoch 104/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5625 - accuracy: 0.7980
# Epoch 105/200
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5585 - accuracy: 0.7879
# Epoch 106/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5049 - accuracy: 0.8283
# Epoch 107/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4885 - accuracy: 0.8182
# Epoch 108/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4690 - accuracy: 0.8586
# Epoch 109/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6249 - accuracy: 0.7576
# Epoch 110/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6418 - accuracy: 0.8182
# Epoch 111/200
# 20/20 [==============================] - 0s 10ms/step - loss: 0.4189 - accuracy: 0.8283
# Epoch 112/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6409 - accuracy: 0.7980
# Epoch 113/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4782 - accuracy: 0.7980
# Epoch 114/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5443 - accuracy: 0.8081
# Epoch 115/200
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6108 - accuracy: 0.7778
# Epoch 116/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5122 - accuracy: 0.8283
# Epoch 117/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5884 - accuracy: 0.7879
# Epoch 118/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4527 - accuracy: 0.7879
# Epoch 119/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4214 - accuracy: 0.8283
# Epoch 120/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4549 - accuracy: 0.8182
# Epoch 121/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4366 - accuracy: 0.8283
# Epoch 122/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4657 - accuracy: 0.8182
# Epoch 123/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4099 - accuracy: 0.7778
# Epoch 124/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4199 - accuracy: 0.8283
# Epoch 125/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5357 - accuracy: 0.8081
# Epoch 126/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4987 - accuracy: 0.7879
# Epoch 127/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3890 - accuracy: 0.8687
# Epoch 128/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5024 - accuracy: 0.7879
# Epoch 129/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4888 - accuracy: 0.7879
# Epoch 130/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5801 - accuracy: 0.7778
# Epoch 131/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4506 - accuracy: 0.8182
# Epoch 132/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5509 - accuracy: 0.8283
# Epoch 133/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5028 - accuracy: 0.8283
# Epoch 134/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6033 - accuracy: 0.8081
# Epoch 135/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4722 - accuracy: 0.8283
# Epoch 136/200
# 20/20 [==============================] - 0s 10ms/step - loss: 0.4180 - accuracy: 0.8283
# Epoch 137/200
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5325 - accuracy: 0.8485
# Epoch 138/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4266 - accuracy: 0.8283
# Epoch 139/200
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4738 - accuracy: 0.8182
# Epoch 140/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4601 - accuracy: 0.8283
# Epoch 141/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4165 - accuracy: 0.8485
# Epoch 142/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4540 - accuracy: 0.7980
# Epoch 143/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4444 - accuracy: 0.8182
# Epoch 144/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.3891 - accuracy: 0.8586
# Epoch 145/200
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4590 - accuracy: 0.8182
# Epoch 146/200
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4403 - accuracy: 0.8283
# Epoch 147/200
# 20/20 [==============================] - 0s 8ms/step - loss: 0.3682 - accuracy: 0.8687
# Epoch 148/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.3141 - accuracy: 0.8889
# Epoch 149/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4712 - accuracy: 0.8384
# Epoch 150/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4866 - accuracy: 0.8283
# Epoch 151/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4184 - accuracy: 0.8182
# Epoch 152/200
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4854 - accuracy: 0.8384
# Epoch 153/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4628 - accuracy: 0.8081
# Epoch 154/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4869 - accuracy: 0.8485
# Epoch 155/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4830 - accuracy: 0.7980
# Epoch 156/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4090 - accuracy: 0.8586
# Epoch 157/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4510 - accuracy: 0.8283
# Epoch 158/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4230 - accuracy: 0.8384
# Epoch 159/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5328 - accuracy: 0.7879
# Epoch 160/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5092 - accuracy: 0.8081
# Epoch 161/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4794 - accuracy: 0.8485
# Epoch 162/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4532 - accuracy: 0.8384
# Epoch 163/200
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4411 - accuracy: 0.8485
# Epoch 164/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4157 - accuracy: 0.8485
# Epoch 165/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4629 - accuracy: 0.8182
# Epoch 166/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4473 - accuracy: 0.8687
# Epoch 167/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4417 - accuracy: 0.8182
# Epoch 168/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5736 - accuracy: 0.7879
# Epoch 169/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4471 - accuracy: 0.8283
# Epoch 170/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4592 - accuracy: 0.8081
# Epoch 171/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4949 - accuracy: 0.8182
# Epoch 172/200
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3384 - accuracy: 0.8283
# Epoch 173/200
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4570 - accuracy: 0.7980
# Epoch 174/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5010 - accuracy: 0.7879
# Epoch 175/200
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5442 - accuracy: 0.8384
# Epoch 176/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5557 - accuracy: 0.8182
# Epoch 177/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.4060 - accuracy: 0.8384
# Epoch 178/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.4708 - accuracy: 0.8283
# Epoch 179/200
# 20/20 [==============================] - 0s 10ms/step - loss: 0.4307 - accuracy: 0.8788
# Epoch 180/200
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4325 - accuracy: 0.8586
# Epoch 181/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6003 - accuracy: 0.7778
# Epoch 182/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5058 - accuracy: 0.8283
# Epoch 183/200
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5685 - accuracy: 0.7778
# Epoch 184/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4643 - accuracy: 0.8283
# Epoch 185/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5701 - accuracy: 0.8081
# Epoch 186/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4121 - accuracy: 0.8081
# Epoch 187/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4131 - accuracy: 0.8283
# Epoch 188/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4918 - accuracy: 0.8283
# Epoch 189/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3943 - accuracy: 0.8283
# Epoch 190/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5379 - accuracy: 0.7778
# Epoch 191/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5570 - accuracy: 0.7980
# Epoch 192/200
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4764 - accuracy: 0.8081
# Epoch 193/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4339 - accuracy: 0.8687
# Epoch 194/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5426 - accuracy: 0.7677
# Epoch 195/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4236 - accuracy: 0.8384
# Epoch 196/200
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6638 - accuracy: 0.7374
# Epoch 197/200
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5137 - accuracy: 0.7677
# Epoch 198/200
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4708 - accuracy: 0.8182
# Epoch 199/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4083 - accuracy: 0.8485
# Epoch 200/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4652 - accuracy: 0.8384
# model is created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('/content/drive/MyDrive/Colab Notebooks/intents.json').read())
words = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/words.pkl','rb'))
classes = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/classes.pkl','rb'))
def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stemming every word - reducing to base form
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)
    return(np.array(bag))
def predict_class(sentence):
    # filter below  threshold predictions
    p = bag_of_words(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
#Creating tkinter GUI
# import tkinter
# from tkinter import *
# def send():
#     msg = EntryBox.get("1.0",'end-1c').strip()
#     EntryBox.delete("0.0",END)
#     if msg != '':
#         ChatBox.config(state=NORMAL)
#         ChatBox.insert(END, "You: " + msg + '\n\n')
#         ChatBox.config(foreground="#446665", font=("Verdana", 12 )) 
#         ints = predict_class(msg)
#         res = getResponse(ints, intents)
#         ChatBox.insert(END, "Bot: " + res + '\n\n')           
#         ChatBox.config(state=DISABLED)
#         ChatBox.yview(END)
# root = Tk()
# root.title("Chatbot")
# root.geometry("400x500")
# root.resizable(width=FALSE, height=FALSE)
# #Create Chat window
# ChatBox = Text(root, bd=0, bg="white", height="8", width="50", font="Arial",)
# ChatBox.config(state=DISABLED)
# #Bind scrollbar to Chat window
# scrollbar = Scrollbar(root, command=ChatBox.yview, cursor="heart")
# ChatBox['yscrollcommand'] = scrollbar.set
# #Create Button to send message
# SendButton = Button(root, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
#                     bd=0, bg="#f9a602", activebackground="#3c9d9b",fg='#000000',
#                     command= send )
# #Create the box to enter message
# EntryBox = Text(root, bd=0, bg="white",width="29", height="5", font="Arial")
# #EntryBox.bind("<Return>", send)
# #Place all components on the screen
# scrollbar.place(x=376,y=6, height=386)
# ChatBox.place(x=6,y=6, height=386, width=370)
# EntryBox.place(x=128, y=401, height=90, width=265)
# SendButton.place(x=6, y=401, height=90)
# root.mainloop()

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD
import random

import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
intents_file = open('/content/drive/MyDrive/Colab Notebooks/intents.json').read()
intents = json.loads(intents_file)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for word in words:
        bag.append(1) if word in pattern_words else bag.append(0)
        
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")

# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=172, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# [(['hi'], 'greeting'), (['hello'], 'greeting'), (['whats', 'up'], 'greeting'), (['sup'], 'greeting'), (['is', 'anyone', 'there'], 'greeting'), (['whats', 'good'], 'greeting'), (['hey'], 'greeting'), (['bye'], 'goodbye'), (['cya'], 'goodbye'), (['see', 'you', 'later'], 'goodbye'), (['goodbye'], 'goodbye'), (['im', 'leaving'], 'goodbye'), (['have', 'a', 'good', 'day'], 'goodbye'), (['how', 'old', 'are', 'you'], 'age'), (['what', 'is', 'your', 'age'], 'age'), (['thanks'], 'thanks'), (['thank', 'you'], 'thanks'), (['thankyou'], 'thanks'), (['ty'], 'thanks'), (['I', 'owe', 'you', 'one'], 'thanks'), (['whats', 'is', 'your', 'name'], 'name'), (['whats', 'your', 'name'], 'name'), (['whats', 'should', 'I', 'call', 'you'], 'name'), (['how', 'should', 'I', 'address', 'you'], 'name'), (['Yes', 'it', 'does'], 'sky_net_yes'), (['Yeah'], 'sky_net_yes'), (['Haha', 'yep'], 'sky_net_yes'), (['yes'], 'sky_net_yes'), (['Indeed'], 'sky_net_yes'), (['Yup'], 'sky_net_yes'), (['Just', 'like', 'the', 'terminator'], 'sky_net_yes'), (['no'], 'sky_net_no'), (['nah'], 'sky_net_no'), (['not', 'really'], 'sky_net_no'), (['thats', 'scary'], 'sky_net_no'), (['singularity'], 'sky_net_no'), (['how', 'are', 'you'], 'how_are_you'), (['how', 'are', 'you', 'doing'], 'how_are_you'), (['what', 'is', 'going', 'on'], 'how_are_you'), (['I', 'am', 'doing', 'great'], 'doing_great'), (['I', 'am', 'well'], 'doing_great'), (['Im', 'great'], 'doing_great'), (['awesome'], 'doing_great'), (['happy'], 'doing_great'), (['better'], 'doing_great'), (['not', 'great'], 'doing_badly'), (['not', 'well'], 'doing_badly'), (['not', 'good'], 'doing_badly'), (['bad'], 'doing_badly'), (['badly'], 'doing_badly'), (['terrible'], 'doing_badly'), (['horrible'], 'doing_badly'), (['awful'], 'doing_badly'), (['sad'], 'doing_badly'), (['wait', 'you', 'watch', 'Netflix'], 'netflix'), (['how', 'do', 'you', 'watch', 'Netflix'], 'netflix'), (['Netflix'], 'netflix'), (['how', 'can', 'you', 'run'], 'quick_run'), (['how', 'do', 'you', 'run'], 'quick_run'), (['how', 'run'], 'quick_run'), (['why', 'run'], 'quick_run'), (['run'], 'quick_run'), (['you', 'real'], 'real_bot'), (['you', 'human'], 'real_bot'), (['you', 'robot'], 'real_bot'), (['you', 'alive'], 'real_bot'), (['you', 'sentient'], 'real_bot'), (['you', 'conscious'], 'real_bot'), (['tell', 'me', 'joke'], 'joke'), (['got', 'any', 'good', 'jokes'], 'joke'), (['got', 'jokes'], 'joke'), (['can', 'you', 'tell', 'joke'], 'joke'), (['tell', 'joke'], 'joke'), (['haha'], 'good_joke'), (['that', 'was', 'funny'], 'good_joke'), (['very', 'funny'], 'good_joke'), (['good', 'one'], 'good_joke'), (['bad', 'joke'], 'bad_joke'), (['trash', 'joke'], 'bad_joke'), (['terrible'], 'bad_joke'), (['not', 'funny'], 'bad_joke'), (['I', 'hate', 'you'], 'hate'), (['you', 'stupid'], 'hate'), (['you', 'dumb'], 'hate'), (['you', 'mean'], 'hate'), (['you', 'my', 'friend'], 'like'), (['I', 'like', 'you'], 'like'), (['I', 'love', 'you'], 'like'), (['you', 'cool'], 'like'), (['you', 'are', 'chill'], 'like'), (['whats', 'favorite', 'show'], 'favorite_show'), (['favorite', 'tv', 'show'], 'favorite_show'), (['Whats', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'film'], 'favorite_movie'), (['best', 'movie'], 'favorite_movie'), (['your', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'movie'], 'favorite_movie'), (['What', 'think', 'about'], 'your_thoughts'), (['What', 'your', 'thoughts'], 'your_thoughts')]
# 99 documents
# 21 classes ['age', 'bad_joke', 'doing_badly', 'doing_great', 'favorite_movie', 'favorite_show', 'good_joke', 'goodbye', 'greeting', 'hate', 'how_are_you', 'joke', 'like', 'name', 'netflix', 'quick_run', 'real_bot', 'sky_net_no', 'sky_net_yes', 'thanks', 'your_thoughts']
# 113 unique lemmatized words ['a', 'about', 'address', 'age', 'alive', 'am', 'any', 'anyone', 'are', 'awesome', 'awful', 'bad', 'badly', 'best', 'better', 'bye', 'call', 'can', 'chill', 'conscious', 'cool', 'cya', 'day', 'do', 'doe', 'doing', 'dumb', 'favorite', 'film', 'friend', 'funny', 'going', 'good', 'goodbye', 'got', 'great', 'haha', 'happy', 'hate', 'have', 'hello', 'hey', 'hi', 'horrible', 'how', 'human', 'i', 'im', 'indeed', 'is', 'it', 'joke', 'just', 'later', 'leaving', 'like', 'love', 'me', 'mean', 'movie', 'my', 'nah', 'name', 'netflix', 'no', 'not', 'old', 'on', 'one', 'owe', 'real', 'really', 'robot', 'run', 'sad', 'scary', 'see', 'sentient', 'should', 'show', 'singularity', 'stupid', 'sup', 'tell', 'terminator', 'terrible', 'thank', 'thanks', 'thankyou', 'that', 'thats', 'the', 'there', 'think', 'thought', 'trash', 'tv', 'ty', 'up', 'very', 'wa', 'wait', 'watch', 'well', 'what', 'whats', 'why', 'yeah', 'yep', 'yes', 'you', 'your', 'yup']
# Training data created
# Epoch 1/172
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:70: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 20/20 [==============================] - 1s 2ms/step - loss: 3.0508 - accuracy: 0.0808
# Epoch 2/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.9614 - accuracy: 0.1414
# Epoch 3/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.9550 - accuracy: 0.1212
# Epoch 4/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.8607 - accuracy: 0.1010
# Epoch 5/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.8438 - accuracy: 0.1313
# Epoch 6/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.6926 - accuracy: 0.2121
# Epoch 7/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.6652 - accuracy: 0.2727
# Epoch 8/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.5926 - accuracy: 0.2828
# Epoch 9/172
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4745 - accuracy: 0.3232
# Epoch 10/172
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2937 - accuracy: 0.3131
# Epoch 11/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.1481 - accuracy: 0.3737
# Epoch 12/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.0443 - accuracy: 0.4141
# Epoch 13/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.9677 - accuracy: 0.4444
# Epoch 14/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.9978 - accuracy: 0.3737
# Epoch 15/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8614 - accuracy: 0.4040
# Epoch 16/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7392 - accuracy: 0.4646
# Epoch 17/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.6229 - accuracy: 0.5354
# Epoch 18/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5482 - accuracy: 0.5051
# Epoch 19/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4925 - accuracy: 0.5354
# Epoch 20/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4406 - accuracy: 0.6061
# Epoch 21/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.2880 - accuracy: 0.6162
# Epoch 22/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.2917 - accuracy: 0.5758
# Epoch 23/172
# 20/20 [==============================] - 0s 3ms/step - loss: 1.2256 - accuracy: 0.5960
# Epoch 24/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.2280 - accuracy: 0.5960
# Epoch 25/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1213 - accuracy: 0.6162
# Epoch 26/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0361 - accuracy: 0.7374
# Epoch 27/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8088 - accuracy: 0.7879
# Epoch 28/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9462 - accuracy: 0.6768
# Epoch 29/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8989 - accuracy: 0.7374
# Epoch 30/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9641 - accuracy: 0.6970
# Epoch 31/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7825 - accuracy: 0.7677
# Epoch 32/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8149 - accuracy: 0.7576
# Epoch 33/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6976 - accuracy: 0.8384
# Epoch 34/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7192 - accuracy: 0.8182
# Epoch 35/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5252 - accuracy: 0.8687
# Epoch 36/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6295 - accuracy: 0.7980
# Epoch 37/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4779 - accuracy: 0.8586
# Epoch 38/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.8081
# Epoch 39/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5337 - accuracy: 0.8586
# Epoch 40/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5660 - accuracy: 0.8283
# Epoch 41/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5104 - accuracy: 0.8081
# Epoch 42/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4367 - accuracy: 0.8990
# Epoch 43/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4942 - accuracy: 0.8687
# Epoch 44/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2750 - accuracy: 0.9495
# Epoch 45/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6236 - accuracy: 0.8081
# Epoch 46/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3774 - accuracy: 0.8889
# Epoch 47/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5068 - accuracy: 0.8687
# Epoch 48/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4239 - accuracy: 0.8889
# Epoch 49/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.8889
# Epoch 50/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3231 - accuracy: 0.8889
# Epoch 51/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3654 - accuracy: 0.8687
# Epoch 52/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4328 - accuracy: 0.8788
# Epoch 53/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8788
# Epoch 54/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3045 - accuracy: 0.9293
# Epoch 55/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4045 - accuracy: 0.8990
# Epoch 56/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3360 - accuracy: 0.8687
# Epoch 57/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3248 - accuracy: 0.8889
# Epoch 58/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3306 - accuracy: 0.8990
# Epoch 59/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2460 - accuracy: 0.9091
# Epoch 60/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3631 - accuracy: 0.8788
# Epoch 61/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.9293
# Epoch 62/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2102 - accuracy: 0.9697
# Epoch 63/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2366 - accuracy: 0.9293
# Epoch 64/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.8990
# Epoch 65/172
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2151 - accuracy: 0.9091
# Epoch 66/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2415 - accuracy: 0.9293
# Epoch 67/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3989 - accuracy: 0.8990
# Epoch 68/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2533 - accuracy: 0.9091
# Epoch 69/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2828 - accuracy: 0.8990
# Epoch 70/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2109 - accuracy: 0.9293
# Epoch 71/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2087 - accuracy: 0.9394
# Epoch 72/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1800 - accuracy: 0.9495
# Epoch 73/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2600 - accuracy: 0.9293
# Epoch 74/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2075 - accuracy: 0.9495
# Epoch 75/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2709 - accuracy: 0.9293
# Epoch 76/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1953 - accuracy: 0.9495
# Epoch 77/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2794 - accuracy: 0.8990
# Epoch 78/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1624 - accuracy: 0.9495
# Epoch 79/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2312 - accuracy: 0.9091
# Epoch 80/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2173 - accuracy: 0.9293
# Epoch 81/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0977 - accuracy: 0.9798
# Epoch 82/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1704 - accuracy: 0.9394
# Epoch 83/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1932 - accuracy: 0.9394
# Epoch 84/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2110 - accuracy: 0.9293
# Epoch 85/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2076 - accuracy: 0.9495
# Epoch 86/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1425 - accuracy: 0.9495
# Epoch 87/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2066 - accuracy: 0.9293
# Epoch 88/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2043 - accuracy: 0.9596
# Epoch 89/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2367 - accuracy: 0.9394
# Epoch 90/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1205 - accuracy: 0.9697
# Epoch 91/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1689 - accuracy: 0.9596
# Epoch 92/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1138 - accuracy: 0.9798
# Epoch 93/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9697
# Epoch 94/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1547 - accuracy: 0.9596
# Epoch 95/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1729 - accuracy: 0.9596
# Epoch 96/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.9293
# Epoch 97/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1848 - accuracy: 0.9293
# Epoch 98/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1780 - accuracy: 0.9495
# Epoch 99/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1099 - accuracy: 0.9697
# Epoch 100/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1199 - accuracy: 0.9798
# Epoch 101/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1333 - accuracy: 0.9596
# Epoch 102/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.9798
# Epoch 103/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1350 - accuracy: 0.9394
# Epoch 104/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1978 - accuracy: 0.9394
# Epoch 105/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1308 - accuracy: 0.9495
# Epoch 106/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1896 - accuracy: 0.9293
# Epoch 107/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1613 - accuracy: 0.9293
# Epoch 108/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1554 - accuracy: 0.9697
# Epoch 109/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1463 - accuracy: 0.9495
# Epoch 110/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.9697
# Epoch 111/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2090 - accuracy: 0.9192
# Epoch 112/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1187 - accuracy: 0.9596
# Epoch 113/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.9798
# Epoch 114/172
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1128 - accuracy: 0.9495
# Epoch 115/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1063 - accuracy: 0.9697
# Epoch 116/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1528 - accuracy: 0.9495
# Epoch 117/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1396 - accuracy: 0.9596
# Epoch 118/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1918 - accuracy: 0.9596
# Epoch 119/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1408 - accuracy: 0.9596
# Epoch 120/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1556 - accuracy: 0.9596
# Epoch 121/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1849 - accuracy: 0.9394
# Epoch 122/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1274 - accuracy: 0.9596
# Epoch 123/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1303 - accuracy: 0.9596
# Epoch 124/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1599 - accuracy: 0.9697
# Epoch 125/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1386 - accuracy: 0.9394
# Epoch 126/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1293 - accuracy: 0.9596
# Epoch 127/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1249 - accuracy: 0.9596
# Epoch 128/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1102 - accuracy: 0.9798
# Epoch 129/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.9798
# Epoch 130/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.9596
# Epoch 131/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1617 - accuracy: 0.9495
# Epoch 132/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1364 - accuracy: 0.9495
# Epoch 133/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1499 - accuracy: 0.9596
# Epoch 134/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.9899
# Epoch 135/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1755 - accuracy: 0.9394
# Epoch 136/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1219 - accuracy: 0.9596
# Epoch 137/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2233 - accuracy: 0.9192
# Epoch 138/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1651 - accuracy: 0.9192
# Epoch 139/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1406 - accuracy: 0.9596
# Epoch 140/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1371 - accuracy: 0.9596
# Epoch 141/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1528 - accuracy: 0.9697
# Epoch 142/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1517 - accuracy: 0.9495
# Epoch 143/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1459 - accuracy: 0.9495
# Epoch 144/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.9697
# Epoch 145/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1137 - accuracy: 0.9697
# Epoch 146/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1084 - accuracy: 0.9798
# Epoch 147/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9697
# Epoch 148/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1315 - accuracy: 0.9293
# Epoch 149/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1534 - accuracy: 0.9394
# Epoch 150/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1105 - accuracy: 0.9697
# Epoch 151/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1316 - accuracy: 0.9596
# Epoch 152/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1813 - accuracy: 0.9394
# Epoch 153/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1030 - accuracy: 0.9596
# Epoch 154/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1233 - accuracy: 0.9394
# Epoch 155/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0965 - accuracy: 0.9798
# Epoch 156/172
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1123 - accuracy: 0.9798
# Epoch 157/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 0.9697
# Epoch 158/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0622 - accuracy: 0.9798
# Epoch 159/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1222 - accuracy: 0.9697
# Epoch 160/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1516 - accuracy: 0.9394
# Epoch 161/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1228 - accuracy: 0.9596
# Epoch 162/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1376 - accuracy: 0.9596
# Epoch 163/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 0.9697
# Epoch 164/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0807 - accuracy: 0.9596
# Epoch 165/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9697
# Epoch 166/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1399 - accuracy: 0.9596
# Epoch 167/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0584 - accuracy: 0.9798
# Epoch 168/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1222 - accuracy: 0.9596
# Epoch 169/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1072 - accuracy: 0.9899
# Epoch 170/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0497 - accuracy: 0.9798
# Epoch 171/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1391 - accuracy: 0.9495
# Epoch 172/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1257 - accuracy: 0.9697
# model created

# %%
# !pip install --upgrade "ibm-watson>=5.3.1"
# Out:
# Requirement already satisfied: ibm-watson>=5.3.1 in /usr/local/lib/python3.7/dist-packages (6.0.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from ibm-watson>=5.3.1) (2.8.2)
# Requirement already satisfied: requests<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from ibm-watson>=5.3.1) (2.27.1)
# Requirement already satisfied: websocket-client==1.1.0 in /usr/local/lib/python3.7/dist-packages (from ibm-watson>=5.3.1) (1.1.0)
# Requirement already satisfied: ibm-cloud-sdk-core==3.*,>=3.3.6 in /usr/local/lib/python3.7/dist-packages (from ibm-watson>=5.3.1) (3.15.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm-watson>=5.3.1) (2.3.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.0 in /usr/local/lib/python3.7/dist-packages (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm-watson>=5.3.1) (1.26.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.5.3->ibm-watson>=5.3.1) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.0->ibm-watson>=5.3.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.0->ibm-watson>=5.3.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.0->ibm-watson>=5.3.1) (2021.10.8)

# %%
import anvil.server

# %%
anvil.server.connect("TYIRZOOL7NRIXVOS4F4S4COP-SLOBDN67A3SHKBDS")

# %%
import json
from ibm_watson import DiscoveryV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
msg = list()
text = str()

# %%
@anvil.server.callable
def responsed(msg1):
    msg.append(msg1)
    ints = predict_class(msg1)
    res = getResponse(ints, intents)
    return res

# %%
# # IBM Tone analyzer
# import json
# from ibm_watson import ToneAnalyzerV3
# from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# authenticator = IAMAuthenticator(api_key)
# tone_analyzer = ToneAnalyzerV3(
#     version='2017-09-21',
#     authenticator=authenticator
# )

# tone_analyzer.set_service_url(https://api.eu-gb.tone-analyzer.watson.cloud.ibm.com/instances/api_key)
# text = " "
# for i in msg:
#     text = text+i
# tone_analysis = tone_analyzer.tone(
#     {'text': text},
#     content_type='application/json'
# ).get_result()
# print(json.dumps(tone_analysis, indent=2))

# %%
@anvil.server.callable
def song_emotion():
    authenticator = IAMAuthenticator(api_key)
    tone_analyzer = ToneAnalyzerV3(
        version='2017-09-21',
        authenticator=authenticator
    
    )

    tone_analyzer.set_service_url(https://api.eu-gb.tone-analyzer.watson.cloud.ibm.com/instances/api_key)
    # text = ""
    # for i in msg:
    #     text = text+i
    len1 = len(msg)
    tone_analysis = tone_analyzer.tone(
        {'text': msg[len1-1]+" "+msg[len1-2]+" "+msg[len1-3]+" "+msg[len1-4]+" "+msg[len1-5]},
        content_type='application/json'
    ).get_result()
    dic1 = dict()
    emotion=tone_analysis["document_tone"]["tones"][0]["tone_name"]
    dic1['emotion'] = emotion
    import requests

    url=f"http://ws.audioscrobbler.com/2.0/?method=tag.gettoptracks&tag={emotion}&api_key={api_key}&format=json&limit=10"
    response = requests.get(url)
    payload = response.json()
    for i in range(10):
        r=payload['tracks']['track'][i]
        dic1[r['name']] = r['url']
    return dic1
# Out:
#   File "<ipython-input-17-56964bd5a980>", line 10
#     tone_analyzer.set_service_url(https://api.eu-gb.tone-analyzer.watson.cloud.ibm.com/instances/api_key)
#                                        ^
# SyntaxError: invalid syntax

# %%
# print(msg)
# # print(text)
# print(len(msg))

# %%
# SONG RECOMMENDATION

# %%
import requests

url=f"http://ws.audioscrobbler.com/2.0/?method=tag.gettoptracks&tag=happy&api_key=0bd531a4ee89cea6f395c2f7fee1b9dc&format=json&limit=5"
response = requests.get(url)
payload = response.json()
# for i in range(4):
r=payload['tracks']['track'][0]
# print(r['url'])
print(payload)
# Out:
# {'tracks': {'track': [{'name': 'Pumped Up Kicks', 'duration': '236', 'mbid': '816b3284-5f24-4f3a-9554-750e0bf5d060', 'url': 'https://www.last.fm/music/Foster+the+People/_/Pumped+Up+Kicks', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Foster the People', 'mbid': 'e0e1a584-dd0a-4bd1-88d1-c4c62895039d', 'url': 'https://www.last.fm/music/Foster+the+People'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '1'}}, {'name': "I'm Yours", 'duration': '242', 'mbid': 'a5a2330e-2fff-4601-a715-6e68a8e98fbf', 'url': 'https://www.last.fm/music/Jason+Mraz/_/I%27m+Yours', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Jason Mraz', 'mbid': '82eb8936-7bf6-4577-8320-a2639465206d', 'url': 'https://www.last.fm/music/Jason+Mraz'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '2'}}, {'name': 'Dog Days Are Over', 'duration': '270', 'mbid': '772ea437-45b3-4868-b3c0-b80526ef0fa3', 'url': 'https://www.last.fm/music/Florence+%252B+the+Machine/_/Dog+Days+Are+Over', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Florence + the Machine', 'mbid': '5fee3020-513b-48c2-b1f7-4681b01db0c6', 'url': 'https://www.last.fm/music/Florence+%252B+the+Machine'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '3'}}, {'name': 'A-Punk', 'duration': '136', 'mbid': '047db898-cedf-48a0-afc2-5b686c9b8840', 'url': 'https://www.last.fm/music/Vampire+Weekend/_/A-Punk', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Vampire Weekend', 'mbid': 'af37c51c-0790-4a29-b995-456f98a6b8c9', 'url': 'https://www.last.fm/music/Vampire+Weekend'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '4'}}, {'name': "Friday I'm in Love", 'duration': '214', 'mbid': '8d9104c6-7d8e-460b-8c3d-2d797f79953d', 'url': 'https://www.last.fm/music/The+Cure/_/Friday+I%27m+in+Love', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'The Cure', 'mbid': '69ee3720-a7cb-4402-b48d-a02c366f2bcf', 'url': 'https://www.last.fm/music/The+Cure'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a ...

# %%
# print(dic1)

# %%
print("Chatbot : Hey there, Wassup ?")
# responded function takes text of user and returns chatbot output
for i in range(5):
    m = input("User : ")
    res = responsed(m)
    print("Chatbot : "+res)
ans = song_emotion()
print("Emotion : "+ans['emotion'])
# Out:
# Chatbot : Hey there, Wassup ?
# User :
# Chatbot : Hate to hear it.
# User : hello
# Chatbot : How dare you address me like that
# User : please play baby song
# Chatbot : Awe thats unfortunate.
# User : play
# Chatbot : Hate to hear it.
# User : bye
# Chatbot : Thank god you're leaving
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-017513ad00d1> in <module>()
#       5     res = responsed(m)
#       6     print("Chatbot : "+res)
# ----> 7 ans = song_emotion()
#       8 print("Emotion : "+ans['emotion'])
#
# NameError: name 'song_emotion' is not defined

# %%
\# song_emotion function would return dictionary consisting of emotion and recommended songs
ans = song_emotion()
print("Emotion : "+ans['emotion'])
ans.pop('emotion')
lst = list(ans.keys())
print("Song Recommendations : ")
for i in range(10):
    print("Song_name : "+lst[i])
    print("Song_URL : "+ans[lst[i]])
